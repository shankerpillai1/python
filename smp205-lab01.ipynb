# %% [markdown]
# # Lab 1

# %% [markdown]
# 1. Shanker Pillai
# 2. 1/20/2023

# %% [markdown]
# ## Markdown Exercises

# %% [markdown]
# **I believe coding has many applications and is a useful skill in almost every scientific field. I hope that being able to program will help me create algorithms and software that has real-world uses.**

# %% [markdown]
#  - *Basic Python*
#  - *General Coding Concepts*
# - *Facts about today's technology landscape*
# - *Collaboration Skills*
# - *Opportunities in the SCI*

# %% [markdown]
# ![alt text](https://media.giphy.com/media/dg0hVakNxI0LaIQDQm/giphy.gif "GIF 1")

# %% [markdown]
# ---

# %% [markdown]
# ## Jupyter Notebook Exercises

# %%
name = input(prompt="What is your name? ")
print("Hello", name, "!")
# Out:
# What is your name?  Shanker
# Hello Shanker !

# %% [markdown]
# The code asked me for my input and outputted it according to the format I gave it.

# %%
name = input(prompt="What is your full name? ")
print("Hello", name, ".")
# Out:
# What is your full name?  Shanker Pillai
# Hello Shanker Pillai .

# %% [markdown]
# The format changed as I expected.

# %%
# %matplotlib inline
import pandas as pd
# Load the PGH 311 Complaint data
data_url = \
"https://data.wprdc.org/datastore/dump/76fda9d0-69be-4dd5-8108-0de7907fc5a4"
complaints = pd.read_csv(data_url, parse_dates=True, index_col="CREATED_ON")
# Produce a graph that shows the number of complaints per month
complaints.resample("M").size().plot();

# %% [markdown]
# Based on how the name is "complaint data" I believe this displays the complaints filed every quarter of the year.

# %% [markdown]
# ![alt text](https://media.giphy.com/media/DKnMqdm9i980E/giphy.gif "Logo Title Text 1")
